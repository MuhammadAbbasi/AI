# %% [markdown]
# <h3>Variable Scope</h3>

# %%
b = 10
def f1():
    a = 5
    print(a)
    print(b)
    if a == 5:
        a = 20
        c = a + 5
        print(a)
        print(b)
        print(c)
f1()

# %%
x = 10
def foo():
    x =20
    if True:
        x = 60
        print(x)
foo()
print(x)

# %% [markdown]
# <h3>Nested Function</h3>

# %%
y=20
def y():
    print('nested')

def x(z):
    print('This is function argument')
    z()
x(y)

# %% [markdown]
# # While loops

# %%
current_number = 1
while current_number <= 5:
    print(current_number)
    current_number += 1

# %%
prompt =  'Enter city : '
while True:
    city = input(prompt).lower() 
    if city == 'quit':
        break
    else:
        print("I'd love to go to " + city.title() + "!")

# %%
cleanest_cities = ["Cheyenne", "Santa Fe", "Tucson", "Great Falls", "Honolulu"]
user_input = ""
while user_input != "q":
    user_input = input("Enter a city, or q to quit:")
    if user_input != "q":
        for a_clean_city in cleanest_cities:
            if user_input == a_clean_city:
                print("It's one of the cleanest cities")
                break
    else:
        print('Its not is cleanest cities')
        break

# %%
keep_looping = True
while keep_looping == True:
    user_input = input("Enter a city, or q to quit:")
    if user_input != "q":
        for a_clean_city in cleanest_cities:
            if user_input == a_clean_city:
                print("It's one of the cleanest cities")
                break
    else:
        keep_looping = False

# %% [markdown]
# Movie Tickets: A movie theater charges different ticket prices depending on
# a person’s age. If a person is under the age of 3, the ticket is free; if they are
# between 3 and 12, the ticket is $10; and if they are over age 12, the ticket is
# $15. Write a loop in which you ask users their age, and then tell them the cost
# of their movie ticket.

# %% [markdown]
# # Classes

# %%
class Patient():
    pass

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Patient():
    def __init__(self, last_name):
        pass

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Patient():
    def __init__(self, last_name):
        self.last_name = last_name
        pass

# %%
pid4343 = Patient("Taleb")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-d37101132d92> in <module>()
# ----> 1 pid4343 = Patient("Taleb")
#
# TypeError: __init__() missing 2 required positional arguments: 'first_name' and 'age'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pid4344 = Patient("Anand")
pid4345 = Patient("Oppenheimer")
pid4346 = Patient("Lin")
pid12902 = Patient("Nilsson")

# %%
class Patient():
    def __init__(self, last_name, first_name, age):
        self.l_n = last_name
        self.f_n = first_name
        self.age = age
        
pid4343 = Patient("Taleb", 'khan' , 61)
# Out:
# Taleb

# %%
pid4344 = Patient("Anand", "Punya", 29)
pid4345 = Patient("Oppenheimer", "Douglas", 15)
pid4346 = Patient("Lin", "Lilly", 48)

print(pid4343.last_name)
pid4344.first_name
# Out:
# Anand
# Oppenheimer
# Lin
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-a73f5445837b> in <module>()
#       4 pid4346 = Patient("Lin", "Lilly", 48)
#       5
# ----> 6 print(pid4343.last_name)
#       7 pid4344.first_name
#
# AttributeError: 'Patient' object has no attribute 'last_name'

# %%
age_of_patient = pid4343.age

# %%
class Patient():
    def __init__(self, last_name, first_name, age):
        self.last_name = last_name
        self.first_name = first_name
        self.age = age
    def say_if_minor(self):
        if self.age < 21:
            print("This patient is a minor")
            
pid12902 = Patient("Nilsson", "Rhonda", 20)
pid12902.
# Out:
# This patient is a minor

# %% [markdown]
# # Classes examples

# %%
class Dog():
    """A simple attempt to model a dog."""
    def __init__(self, name, age):
        """Initialize name and age attributes."""
        self.name = name
        self.age = age
        
    def sit(self):
        """Simulate a dog sitting in response to a command."""
        print(self.name.title() + " is now sitting.")
    def roll_over(self):
        """Simulate rolling over in response to a command."""
        print(self.name.title() + " rolled over!")

# %%
my_dog = Dog('willie', 6)
my_dog.

# %%
print("My dog's name is " + my_dog.name.title() + ".")
print("My dog is " + str(my_dog.age) + " years old.")
# Out:
# My dog's name is Willie.
# My dog is 6 years old.

# %%
my_dog.sit()
# Out:
# Willie is now sitting.

# %%
my_dog.roll_over()

# %%
your_dog = Dog('gucy', 3)

# %%
print("\nYour dog's name is " + your_dog.name.title() + ".")
print("Your dog is " + str(your_dog.age) + " years old.")
your_dog.sit()

# %% [markdown]
# <h2>Assignment Time</h2>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # More concepts on Classes

# %%
class Car():
    """A simple attempt to represent a car."""
    def __init__(self, make, model, year):
        """Initialize attributes to describe a car."""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
    def read_odometer(self):
        print("This car has " + str(self.odometer_reading) + " miles on it.")
    def update_odometer(self, mileage):
        self.odometer_reading = mileage

# %%
my_new_car = Car('audi', 'a4', 2016)
my_new_car.update_odometer(50)
my_new_car.read_odometer()
# Out:
# This car has 50 miles on it.

# %%
my_new_car.odometer_reading = 23
my_new_car.read_odometer()
# Out:
# This car has 23 miles on it.

# %%
Add a default value

Add Method 
    
    
Call Method
my_new_car.read_odometer()


Modify Attribute value


Update attribute through Method



Now Call and check
my_new_car.update_odometer(23)
my_new_car.read_odometer()


Little logic
    """Set the odometer reading to the given value.
    Reject the change if it attempts to roll the odometer back."""
def update_odometer(self, mileage):
    if mileage >= self.odometer_reading:
        self.odometer_reading = mileage
    else:
        print("You can't roll back an odometer!")

# %% [markdown]
# # Inheritance

# %%
class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicles."""
    def __init__(self, make, model, year , oil):
        """Initialize attributes of the parent class."""
        super().__init__(make, model, year )
        self.oil = oil

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016  , 25)
my_tesla.oil
# Out:
# 25

# %%
ADD battery and method to printt battery size
self.battery_size = 70
def describe_battery(self):
    """Print a statement describing the battery size."""
    print("This car has a " + str(self.battery_size) + "-kWh battery.")
    
Call a battery method
my_tesla.describe_battery()

# %%
OverRide parent class method in child class
def fill_gas_tank():
    """Electric cars don't have gas tanks."""
    print("This car doesn't need a gas tank!")

# %% [markdown]
# # Instances as Attributes

# %%
class Battery():
    """A simple attempt to model a battery for an electric car."""
    def __init__(self, battery_size=70):
        """Initialize the battery's attributes."""
        self.battery_size = battery_size
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print("This car has a " + str(self.battery_size) + "-kWh battery.")

# %%
Add this attribute to electric car classs
self.battery = Battery()
my_tesla.battery.describe_battery()

def get_range(self):
 """Print a statement about the range this battery provides."""
 if self.battery_size == 70:
 range = 240
 elif self.battery_size == 85:
 range = 270

 message = "This car can go approximately " + str(range)
 message += " miles on a full charge."
 print(message)
